# %% [markdown]
# /Volumes/workspace/default/capstoneproject/S&P500_Data_Clean/spx_with_indicators

# %%
df = spark.read.format("delta") \
    .option("versionAsOf", 0) \
    .load("/Volumes/workspace/default/capstoneproject/S&P500_Data_Clean/spx_with_indicators")

display(df)

# %%
# %sql
select * from df

# %%
# %sql
describe spx_clean;
