# %%
# %sql
SELECT * FROM workspace.default.capstonetrades_sma20_50_200

# %%
# %sql
SELECT * FROM workspace.default.capstonetrades_sma20_50

# %%
# %sql
select * from workspace.default.capstonetrades_closesma200

# %%
# %sql
select * from workspace.default.capstonetrades_rsi40

# %%
# %sql 
select * from workspace.default.spx_with_indicators

# %%
# %sql
select * from workspace.default.capstone_daily_model_data

# %%
# %sql
select * from workspace.default.capstone_trade_labels

# %%
# %sql
select * from workspace.default.capstone_trade_model_data

# %%
# %sql
SELECT
    profitable,
    COUNT(*) AS trade_count
FROM workspace.default.capstone_trade_model_data
GROUP BY profitable

# %%
# %sql
SELECT 
    strategy,
    profitable,
    COUNT(*) AS trade_count
FROM workspace.default.capstone_trade_model_data
GROUP BY strategy, profitable
ORDER BY strategy, profitable;

# %%
# %sql
select * from sp500_with_indicators

# %%
# %sql
select * from workspace.default.capstonetrades_closesma200_v2

# %%
# %sql
select * from workspace.default.capstonetrades_sma20_50_v2

# %%
# %sql
select * from workspace.default.capstonetrades_sma20_50_200_v2

# %%
# %sql
select * from workspace.default.capstonetrades_rsi40_v2

# %%
# %sql
select * from workspace.default.capstone_daily_model_data_v2

# %%
# %sql
select * from workspace.default.capstone_trade_labels_v2

# %%
# %sql
select * from workspace.default.capstone_trade_model_data_v2

# %%
# %sql
SELECT
    profitable,
    COUNT(*) AS trade_count
FROM workspace.default.capstone_trade_model_data_v2
GROUP BY profitable

# %%
# %sql
SELECT column_name FROM system.information_schema.columns WHERE table_name = 'capstone_trade_model_data_v2';
